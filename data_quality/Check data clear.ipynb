# %%
import pandas as pd
from ydata_profiling import ProfileReport
df = pd.read_csv('tz_opendata_z01012024_po01012025.csv', sep=';')
profile = ProfileReport(df, title="Звіт про чистоту даних")
profile.to_file("data_quality_report.html")
# Out:
# C:\Users\Bruger\AppData\Local\Temp\ipykernel_10440\114424985.py:3: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('tz_opendata_z01012024_po01012025.csv', sep=';')
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
